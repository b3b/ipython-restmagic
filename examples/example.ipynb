# %%
import pandas as pd

# %%
# %load_ext restmagic

# %% [markdown]
# ##  Single line query

# %%
ug = %rest GET http://httpbin.org/user-agent
print('\nUser agent passed:\t' + ug.json()['user-agent'])
# Out:
# < GET /user-agent HTTP/1.1
# < Host: httpbin.org
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# <
#
# > HTTP/1.1 200 OK
# > Connection: keep-alive
# > Server: gunicorn/19.9.0
# > Date: Fri, 07 Sep 2018 11:13:26 GMT
# > Content-Type: application/json
# > Content-Length: 45
# > Access-Control-Allow-Origin: *
# > Access-Control-Allow-Credentials: true
# > Via: 1.1 vegur
# >
# {
#   "user-agent": "python-requests/2.19.1"
# }
#
#
# User agent passed:	python-requests/2.19.1

# %% [markdown]
# ## Cookies header

# %%
# %%rest
# GET  https://httpbin.org/cookies
# Cookie: cornmeal=porridge;only=carriage
# Out:
# < GET /cookies HTTP/1.1
# < Host: httpbin.org
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# < Cookie: cornmeal=porridge;only=carriage
# <
#
# > HTTP/1.1 200 OK
# > Connection: keep-alive
# > Server: gunicorn/19.9.0
# > Date: Fri, 07 Sep 2018 11:14:28 GMT
# > Content-Type: application/json
# > Content-Length: 75
# > Access-Control-Allow-Origin: *
# > Access-Control-Allow-Credentials: true
# > Via: 1.1 vegur
# >
# {
#   "cookies": {
#     "cornmeal": "porridge",
#     "only": "carriage"
#   }
# }
# <Response [200]>

# %% [markdown]
# ## Post form

# %%
# %%rest
# POST https://httpbin.org/post
# Content-Type: application/x-www-form-urlencoded
#
# username=Gena&email=zoo@example.org
# Out:
# < POST /post HTTP/1.1
# < Host: httpbin.org
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# < Content-Type: application/x-www-form-urlencoded
# < Content-Length: 35
# <
# < username=Gena&email=zoo@example.org
# > HTTP/1.1 200 OK
# > Connection: keep-alive
# > Server: gunicorn/19.9.0
# > Date: Fri, 07 Sep 2018 11:16:44 GMT
# > Content-Type: application/json
# > Content-Length: 478
# > Access-Control-Allow-Origin: *
# > Access-Control-Allow-Credentials: true
# > Via: 1.1 vegur
# >
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "email": "zoo@example.org",
#     "username": "Gena"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "35",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.19.1"
#   },
#   "json": null,
# ...

# %% [markdown]
# ## Post JSON data

# %%
# %%rest
# POST http://httpbin.org/post
# Content-Type: application/json
#
# {
#     "key": "value",
#     "array here": [
#         "item 1",
#         "item 2"
#     ]
# }
# Out:
# < POST /post HTTP/1.1
# < Host: httpbin.org
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# < Content-Type: application/json
# < Content-Length: 84
# <
# < {
#     "key": "value",
#     "array here": [
#         "item 1",
#         "item 2"
#     ]
# }
# > HTTP/1.1 200 OK
# > Connection: keep-alive
# > Server: gunicorn/19.9.0
# > Date: Fri, 07 Sep 2018 11:18:51 GMT
# > Content-Type: application/json
# > Content-Length: 581
# > Access-Control-Allow-Origin: *
# > Access-Control-Allow-Credentials: true
# > Via: 1.1 vegur
# >
# {
#   "args": {},
#   "data": "{\n    \"key\": \"value\",\n    \"array here\": [\n        \"item 1\",\n        \"item 2\"\n    ]\n}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "84",
#     "Content-Type": "application/json",
#     "Host": "httpbin.org",
# ...

# %% [markdown]
# ## Get top 10 forked projects from the GitHub, for the "ipython" query

# %%
# %%rest
# GET https://api.github.com/search/repositories?q=ipython&sort=forks&per_page=10
# Accept: application/vnd.github.v3+json
# Out:
# < GET /search/repositories?q=ipython&sort=forks&per_page=10 HTTP/1.1
# < Host: api.github.com
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: application/vnd.github.v3+json
# < Connection: keep-alive
# <
#
# > HTTP/1.1 200 OK
# > Server: GitHub.com
# > Date: Fri, 07 Sep 2018 11:30:09 GMT
# > Content-Type: application/json; charset=utf-8
# > Transfer-Encoding: chunked
# > Status: 200 OK
# > X-RateLimit-Limit: 10
# > X-RateLimit-Remaining: 8
# > X-RateLimit-Reset: 1536319855
# > Cache-Control: no-cache
# > X-GitHub-Media-Type: github.v3; format=json
# > Link: <https://api.github.com/search/repositories?q=ipython&sort=forks&per_page=10&page=2>; rel="next", <https://api.github.com/search/repositories?q=ipython&sort=forks&per_page=10&page=100>; rel="last"
# > Access-Control-Expose-Headers: ETag, Link, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval
# ...

# %%
# Last response object is available in "_" variable
response = _
print("Response object type:\t{}".format(type(response)))

df = pd.DataFrame(response.json()['items'], columns=('full_name', 'forks_count', 'watchers'))
df.set_index('full_name', inplace=True)
df.plot(kind='barh')
df
# Out:
# Response object type:	<class 'requests.models.Response'>
#                                             forks_count  watchers
# full_name
# wesm/pydata-book                                   6021      6535
# donnemartin/data-science-ipython-notebooks         4031     13684
# ipython/ipython                                    3641     12986
# jrjohansson/scientific-python-lectures             1315      2250
# jdwittenauer/ipython-notebooks                     1084      1929
# jupyterhub/jupyterhub                               824      3587
# PipelineAI/pipeline                                 774      2939
# powerline/powerline                                 741      9298
# ogrisel/parallel_ml_tutorial                        571      1443
# jadianes/spark-py-notebooks                         564       825

# %% [markdown]
# ## Follow Github User
# Personal API token is required to perform the call: https://blog.github.com/2013-05-16-personal-api-tokens/

# %%
# %%rest PUT https://api.github.com/user/following/gvanrossum
# Authorization: Token 87eebb7c2a6c72c5e27219e39b02b8b9dbca2615
# Out:
# < PUT /user/following/gvanrossum HTTP/1.1
# < Host: api.github.com
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# < Authorization: Token 87eebb7c2a6c72c5e27219e39b02b8b9dbca2615
# < Content-Length: 0
# <
#
# > HTTP/1.1 204 No Content
# > Server: GitHub.com
# > Date: Fri, 07 Sep 2018 11:30:44 GMT
# > Content-Type: application/octet-stream
# > Status: 204 No Content
# > X-RateLimit-Limit: 5000
# > X-RateLimit-Remaining: 4989
# > X-RateLimit-Reset: 1536320177
# > X-OAuth-Scopes: public_repo, user:follow
# > X-Accepted-OAuth-Scopes: user, user:follow
# > X-GitHub-Media-Type: github.v3; format=json
# > Access-Control-Expose-Headers: ETag, Link, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval
# > Access-Control-Allow-Origin: *
# > Strict-Transport-Security: max-age=31536000; includeSubdomains; preload
# ...

# %% [markdown]
# ### Unfollow GitHub user

# %%
# %%rest DELETE https://api.github.com/user/following/gvanrossum
# Authorization: Token 87eebb7c2a6c72c5e27219e39b02b8b9dbca2615
# Out:
# < DELETE /user/following/gvanrossum HTTP/1.1
# < Host: api.github.com
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# < Authorization: Token 87eebb7c2a6c72c5e27219e39b02b8b9dbca2615
# < Content-Length: 0
# <
#
# > HTTP/1.1 204 No Content
# > Server: GitHub.com
# > Date: Fri, 07 Sep 2018 11:30:50 GMT
# > Content-Type: application/octet-stream
# > Status: 204 No Content
# > X-RateLimit-Limit: 5000
# > X-RateLimit-Remaining: 4988
# > X-RateLimit-Reset: 1536320177
# > X-OAuth-Scopes: public_repo, user:follow
# > X-Accepted-OAuth-Scopes: user, user:follow
# > X-GitHub-Media-Type: github.v3; format=json
# > Access-Control-Expose-Headers: ETag, Link, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval
# > Access-Control-Allow-Origin: *
# > Strict-Transport-Security: max-age=31536000; includeSubdomains; preload
# ...

# %% [markdown]
# ## Search GitHub for "pritn" string in Python code

# %%
# %%rest
# GET https://api.github.com/search/code?q=pritn+in:file+language:python
# Authorization: Token 87eebb7c2a6c72c5e27219e39b02b8b9dbca2615
# Out:
# < GET /search/code?q=pritn+in:file+language:python HTTP/1.1
# < Host: api.github.com
# < User-Agent: python-requests/2.19.1
# < Accept-Encoding: gzip, deflate
# < Accept: */*
# < Connection: keep-alive
# < Authorization: Token 87eebb7c2a6c72c5e27219e39b02b8b9dbca2615
# <
#
# > HTTP/1.1 200 OK
# > Server: GitHub.com
# > Date: Fri, 07 Sep 2018 11:33:36 GMT
# > Content-Type: application/json; charset=utf-8
# > Transfer-Encoding: chunked
# > Status: 200 OK
# > X-RateLimit-Limit: 30
# > X-RateLimit-Remaining: 29
# > X-RateLimit-Reset: 1536320076
# > Cache-Control: no-cache
# > X-OAuth-Scopes: public_repo, user:follow
# > X-Accepted-OAuth-Scopes:
# > X-GitHub-Media-Type: github.v3; format=json
# > Link: <https://api.github.com/search/code?q=pritn+in%3Afile+language%3Apython&page=2>; rel="next", <https://api.github.com/search/code?q=pritn+in%3Afile+language%3Apython&page=23>; rel="last"
# ...

# %%
data = _.json()
urls = [i['html_url'] for i in data['items']]
print('\n'.join(urls))
print("== {0} of total {1} ==".format(len(urls), data['total_count']))
# Out:
# https://github.com/Ramieltje/octotelegram/blob/a5a15408ce586c6defdcbd54a6fae7195deb38dd/CS1301%20exercises/Hello%20world.py
# https://github.com/abdallah-ali-abdallah/Simply-Raspberry-Pi-Book/blob/6f273337b76ba8083abf74cd9652ad187896392c/Attachments/1-%20Python%20Examples%20(Source%20Codes)/4-1%20Motion%20Detector.py
# https://github.com/runei/IA/blob/77fa1e103162e67b7823ca1ea4dbed396afb3a88/trabDCG.py
# https://github.com/infixsrf/Trash/blob/4d0493cdad38e48f3f63a9ef95877fa52df7bd4c/programmer.py
# https://github.com/CHTramp/Git-/blob/90e8339a52a571c88d2b6e68e9475593c846517f/Python%E8%AF%BE%E7%A8%8B%E4%BB%A3%E7%A0%81/%E8%AF%BE%E7%A8%8B%E5%AD%A6%E4%B9%A0%E4%BB%A3%E7%A0%81/day6-%E5%87%BD%E6%95%B0%E6%93%8D%E4%BD%9C/%E5%87%BD%E6%95%B0%E7%AC%AC%E4%BA%8C%E9%83%A8%E5%88%86%E7%9A%84homework.py
# https://github.com/lxxcumt/learnpython/blob/b63b01b31c283962576cd0dc2d55ee97e9f48d13/ex25.py
# ...
